# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Step 2: Import libraries
import pandas as pd
import os

# %%
# Step 3: Read Excel (no header)
excel_path = "/content/drive/MyDrive/dem_recall.xlsx"

df = pd.read_excel(excel_path, header=None)

# 👉 Assuming your values are in FIRST column
excel_values = df[0].astype(str).str.strip()

print("Excel sample:")
print(excel_values.head())
# Out:
# Excel sample:
# 0    001-2
# 1    003-0
# 2    005-0
# 3    005-2
# 4    007-3
# Name: 0, dtype: object

# %%
# Step 4: Read ALL folder names inside 'cookie'
base_path = "/content/drive/MyDrive/dementia/recall/processed_audios"

folder_names = [
    name.strip()
    for name in os.listdir(base_path)
    if os.path.isdir(os.path.join(base_path, name))
]

print("Folder sample:")
print(folder_names[:5])
# Out:
# Folder sample:
# ['023-0', '029-0', '030-0', '024-1', '029-1']

# %%
# Step 5: Normalize (IMPORTANT for matching)
excel_values = excel_values.str.lower()
folder_names = [f.lower() for f in folder_names]

# %%
# Step 6: Find missing (Excel but NOT in folders)
missing_in_drive = sorted(set(excel_values) - set(folder_names))

print("Missing entries:")
print(missing_in_drive)
# Out:
# Missing entries:
# ['001-2', '172-2', '220-1', '334-1', '343-0', '368-0', '450-1', '544-1', '573-0', '592-0', '594-0', '595-0', '598-0', '601-0', '609-0', '610-0', '615-0', '620-0', '624-0', '635-0', '636-0', '639-0', '650-0', '651-0', '656-0', '689-0', '690-0', '698-0', '702-0', '703-0', '704-0', '705-0', '707-0']
