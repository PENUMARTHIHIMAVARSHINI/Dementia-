# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Step 2: Import libraries
import pandas as pd
import os

# %%
# Step 3: Read Excel (no header)
excel_path = "/content/drive/MyDrive/dem_fluency.xlsx"

df = pd.read_excel(excel_path, header=None)

# 👉 Assuming your values are in FIRST column
excel_values = df[0].astype(str).str.strip()

print("Excel sample:")
print(excel_values.head())
# Out:
# Excel sample:
# 0    001-0
# 1    001-2
# 2    003-0
# 3    005-0
# 4    005-2
# Name: 0, dtype: object

# %%
# Step 4: Read ALL folder names inside 'cookie'
base_path = "/content/drive/MyDrive/dementia/fluency/processed_audios"

folder_names = [
    name.strip()
    for name in os.listdir(base_path)
    if os.path.isdir(os.path.join(base_path, name))
]

print("Folder sample:")
print(folder_names[:5])
# Out:
# Folder sample:
# ['010-1', '010-2', '005-0', '010-0', '005-2']

# %%
# Step 5: Normalize (IMPORTANT for matching)
excel_values = excel_values.str.lower()
folder_names = [f.lower() for f in folder_names]

# %%
# Step 6: Find missing (Excel but NOT in folders)
missing_in_drive = sorted(set(excel_values) - set(folder_names))

print("Missing entries:")
print(missing_in_drive)
# Out:
# Missing entries:
# ['010-4', '016-0', '016-1', '016-3', '016-4', '018-0', '023-0', '023-2', '024-1', '024-2', '029-0', '029-1', '030-0', '030-1', '033-0', '033-1', '033-2', '033-3', '051-0', '051-3', '157-0', '157-2', '164-1', '164-3', '168-0', '172-1', '172-2', '172-3', '173-1', '178-1', '183-0', '183-1', '183-3', '203-0', '203-1', '207-0', '212-0', '212-1', '212-2', '212-3', '213-1', '213-2', '213-3', '223-0', '223-1', '234-0', '235-0', '235-2', '237-1', '237-2', '238-0', '244-0', '252-0', '350-1', '609-0', '610-0', '615-0', '620-0', '624-0', '635-0', '636-0', '639-0', '640-0', '650-0']
